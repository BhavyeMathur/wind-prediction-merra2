# %%
from plot import *

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="AUTCNVRN",
                           level=0, folder="raw", cmap=cmr.ocean,
                           data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='855f844b-01a4-4bd3-8858-afbbf7ae008c'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="BKGERR",
                           level=0, folder="raw", cmap=cmr.sunburst,
                           data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='1b05456c-e281-4c4b-a23a-90b3acf4e9cf'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="COLCNVRN",
                           level=0, folder="raw", cmap=cmr.ocean,
                           data_processing=lambda data: data ** (1 / 5))
# Out:
# <div id='0265fb7a-cd57-45cc-8950-6378ea405baa'></div>

# %%
# %matplotlib notebook

for var in ["COLCNVSN", "CUCNVCI", "CUCNVCL", "CUCNVRN"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.ocean,
                               data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='fc564dfa-f1b2-4de4-91d4-2eba793ebdf1'></div>
# <div id='f95889b4-8739-4de6-88cd-ca2e1d019572'></div>
# <div id='f3b9fe94-e08b-44f1-a8e9-7bd5a9a7572e'></div>
# <div id='87a44c0b-c6cd-4a52-b0ef-a338632bc4a3'></div>

# %%
# %matplotlib notebook

for var in ["DHDT_ANA", "DHDT_BKG", "DHDT_RAD", "DHDT_RAY"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.iceburn, diverging=True)
# Out:
# <div id='5218e1d1-f9b0-404d-82ea-478692e44053'></div>
# <div id='88d4a544-e569-4358-9a70-cf1c4cb7cdb8'></div>
# <div id='2be47abb-3a04-4910-ab05-76242f12c3d0'></div>
# <div id='88880085-c0e5-497c-81bd-7a6bff5be1ba'></div>

# %%
# %matplotlib notebook

for var in ["DHDT_FRI", "DHDT_DYN", "DHDT_PHY", "DHDT_RES"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.iceburn, diverging=True,
                               data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='5bf0d1c7-428e-4246-b902-1240fa356c95'></div>
# <div id='c98351c3-97e0-40dc-b98c-34bc07071aa1'></div>
# <div id='f64ba698-1a3a-45cb-a761-9bc3b99845eb'></div>
# <div id='469219c1-6104-447d-9fc4-c7b682b90cca'></div>

# %%
# %matplotlib notebook

for var in ["DHDT_MST", "DHDT_ORO", "DHDT_CUF"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.iceburn, diverging=True,
                               data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
                                   np.power(-data, 1 / 4)))
# Out:
# <div id='ea08c97c-db10-46ff-a8ed-27f9d374bc95'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1286281705.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1286281705.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1286281705.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1286281705.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1286281705.py:6: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DHDT_TRB",
                           level=0, folder="raw", cmap=cmr.iceburn, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
                               np.power(-data, 1 / 2)))
# Out:
# <div id='9945a61d-8791-4a2f-87e9-df96c5fa2aa4'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/36962070.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/36962070.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/36962070.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/36962070.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/36962070.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DKDT_ANA", "DKDT_BKG", "DKDT_RAY"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.redshift, diverging=True,
                               data_processing=lambda data: data)
# Out:
# <div id='85746b2e-7986-4ce4-af6c-d79cfaec3cf0'></div>
# <div id='d8d9ec67-14e2-4c38-8ac2-b3093d4c8d94'></div>
# <div id='9f758ecf-c302-4542-b1df-b9573c3a5c70'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DKDT_DYN",
                           level=0, folder="raw", cmap=cmr.redshift, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
                               np.power(-data, 1 / 2)))
# Out:
# <div id='179e3499-d6fd-425e-a7e3-bab480e02d79'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2883832864.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2883832864.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2883832864.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2883832864.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2883832864.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DKDT_GWD", "DKDT_INT", "DKDT_PHY", "DKDT_PHYPHY", "DKDT_SRF", "DKDT_TRB"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.redshift, diverging=True,
                               data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
                                   np.power(-data, 1 / 4)))
# Out:
# <div id='62838108-2030-4949-a3bb-32425d82af4a'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2557305539.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2557305539.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2557305539.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2557305539.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/2557305539.py:6: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DKDT_GWDRES", "DKDT_MST", "DKDT_ORO", "DKDT_TOP"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.redshift, diverging=True,
                               data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
                                   np.power(-data, 1 / 5)))
# Out:
# <div id='a449b329-e153-4562-9045-526e459ca53a'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3878467066.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3878467066.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3878467066.py:6: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3878467066.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3878467066.py:6: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DMDT_ANA"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.seaweed, diverging=True,
                               data_processing=lambda data: data)
# Out:
# <div id='2b309e70-8ab4-4031-abff-491e79568718'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DMDT_DYN",
                           level=0, folder="raw", cmap=cmr.seaweed, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
                               np.power(-data, 1 / 2)))
# Out:
# <div id='51116613-e0a4-4a92-a1ce-60af2ef1fd8a'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/360539831.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/360539831.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/360539831.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 2)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/360539831.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 2)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/360539831.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DMDT_PHY",
                           level=0, folder="raw", cmap=cmr.seaweed, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
                               np.power(-data, 1 / 5)))
# Out:
# <div id='76990139-a885-457c-b4b8-2e3f4d307737'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3885753709.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3885753709.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3885753709.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3885753709.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/3885753709.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DOXDT_ANA"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.pride, diverging=True,
                               data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='eebb6fe0-255b-45a4-940f-5deed153eb78'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DOXDT_DYN",
                           level=0, folder="raw", cmap=cmr.pride, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 1.5)) - np.nan_to_num(
                               np.power(-data, 1 / 1.5)))
# Out:
# <div id='deb130b6-c5da-465b-b746-6b8ed6944040'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1831723217.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 1.5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1831723217.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 1.5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1831723217.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 1.5)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1831723217.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 1.5)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/1831723217.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["DOXDT_CHM", "DOXDT_PHY"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.pride, diverging=True,
                               data_processing=lambda data: data)
# Out:
# <div id='55ecf752-bf38-4611-96d0-f8d4f57bce02'></div>
# <div id='8780146f-0619-4a63-b9c4-9cc340371882'></div>

# %%
# %matplotlib notebook

for var in ["DPDT_ANA", "DPDT_DYN", "DPDT_PHY"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.holly, diverging=True,
                               data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='22fd86f4-d9bd-482b-8006-2c03898b8ee4'></div>
# <div id='3d4ebf67-3f72-4205-b81c-f8d27e2273aa'></div>
# <div id='81ca69f3-8656-48d1-af33-c422556b6fe6'></div>

# %%
# %matplotlib notebook

for var in ["DQIDT_ANA", "DQIDT_DYN", "DQIDT_MST", "DQIDT_PHY", "DQVDT_ANA", "DQVDT_CHM", "DQVDT_DYN", "DQVDT_PHY",
            "DQVDT_TRB"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.horizon, diverging=True,
                               data_processing=lambda data: np.cbrt(data))
# Out:
# <div id='039749a1-c74f-4455-92f4-1f6f175b170c'></div>
# <div id='f6ffd954-77ae-4d08-9347-27a80fa4d2b0'></div>
# <div id='4bc10650-2e8f-46e6-8cd7-63225a335e76'></div>
# <div id='5a9a2179-e4a0-492b-a24a-3ebaf4721ec3'></div>
# <div id='c674bbc1-b409-47c4-993c-232ccd3666ec'></div>
# <div id='e6c113af-8f80-45c5-8244-66284a2f48b0'></div>
# <div id='093ca922-a417-403b-b168-5525bcd71434'></div>
# <div id='63f0c6f4-abae-402b-bc92-6abc14469763'></div>
# <div id='d7ab70c8-ed8b-4830-864b-1e3e9c2029d3'></div>

# %%
# %matplotlib notebook

plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable="DQVDT_MST",
                           level=0, folder="raw", cmap=cmr.horizon, diverging=True,
                           data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
                               np.power(-data, 1 / 4)))
# Out:
# <div id='08369dd5-a33b-463d-ae50-e607eb66598e'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/225251260.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/225251260.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/225251260.py:5: RuntimeWarning: invalid value encountered in power
#   data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/225251260.py:6: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/225251260.py:5: RuntimeWarning: invalid value encountered in power
# ...

# %%
# %matplotlib notebook

for var in ["PRECLS", "PRECCU", "PRECSN"]:
    plot_contour_grid_at_level("MERRA2_100.tavg1_2d_int_Nx.1980{:0>2}01.nc4", variable=var,
                               level=0, folder="raw", cmap=cmr.arctic, diverging=False,
                               data_processing=lambda data: np.nan_to_num(np.power(data, 1 / 4)) - np.nan_to_num(
                                   np.power(-data, 1 / 4)))
# Out:
# <div id='bc7c5c2b-f9a5-4de9-ad44-28a44de4df05'></div>
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/598021049.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/598021049.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/598021049.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/598021049.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# /var/folders/r5/mzzh3rn14lgb2__wr5h7swqm0000gn/T/ipykernel_89596/598021049.py:7: RuntimeWarning: invalid value encountered in power
#   np.power(-data, 1 / 4)))
# ...
