# %%
from matplotlib.animation import FuncAnimation

from plot import *

# %%
def animate_interactive_variable_at_time(filename: str,
                                         variable: str,
                                         time: int,
                                         folder: str = "compressed",
                                         output_dir: str = "assets/graphs",
                                         file_format: str = "mp4",
                                         fps: int = 10,
                                         interpolation_levels: int = 8,
                                         **kwargs):

    px = 1 / plt.rcParams["figure.dpi"]
    fig, ax1, ax2 = create_1x2_plot(title="", figsize=(1728 * px, 1080 * px), width_ratios=(98, 2))

    def animate(i):
        print(f"Frame {i}/{frames}")

        ax1.clear()
        ax2.clear()

        i /= interpolation_levels
        if i > 71:
            i = 142 - i

        plot_variable_at_time_and_level(filename, variable, time, i, folder, fig_ax1_ax2=(fig, ax1, ax2), **kwargs)

    frames = 71 * interpolation_levels
    if file_format == "gif":
        frames *= 2

    anim = FuncAnimation(fig, animate, frames=frames, interval=1, blit=True)
    output_file = f"{variable}-{filename.split('.')[-2]}-{1 + time * 3:0>2}:30"
    anim.save(f"{output_dir}/{output_file}-{interpolation_levels}.{file_format}", fps=fps)

# %%
animate_interactive_variable_at_time("MERRA2_100.tavg3_3d_asm_Nv.19800101.nc4", "U", time=0,
                                     folder="compressed/wind", lat_start=70, lat_end=90)
# Out:
# <div id='7f4a5ad7-537b-4fa9-98b3-1b728fb17d9e'></div>
# Frame 0/568
# Frame 0/568
# Frame 1/568
# Frame 2/568
# Frame 3/568
# Frame 4/568
# Frame 5/568
# Frame 6/568
# Frame 7/568
# Frame 8/568
# Frame 9/568
# Frame 10/568
# Frame 11/568
# Frame 12/568
# Frame 13/568
# Frame 14/568
# Frame 15/568
# Frame 16/568
# Frame 17/568
# Frame 18/568
# Frame 19/568
# Frame 20/568
# Frame 21/568
# Frame 22/568
# Frame 23/568
# Frame 24/568
# Frame 25/568
# Frame 26/568
# Frame 27/568
# Frame 28/568
# Frame 29/568
# Frame 30/568
# Frame 31/568
# Frame 32/568
# Frame 33/568
# Frame 34/568
# Frame 35/568
# Frame 36/568
# Frame 37/568
# Frame 38/568
# Frame 39/568
# Frame 40/568
# Frame 41/568
# Frame 42/568
# Frame 43/568
# Frame 44/568
# Frame 45/568
# Frame 46/568
# Frame 47/568
# Frame 48/568
# Frame 49/568
# Frame 50/568
# Frame 51/568
# Frame 52/568
# Frame 53/568
# Frame 54/568
# Frame 55/568
# Frame 56/568
# Frame 57/568
# Frame 58/568
# Frame 59/568
# Frame 60/568
# Frame 61/568
# ...
